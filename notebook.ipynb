# %% [markdown]
# <a href="https://colab.research.google.com/github/Diego-LeivaC/Quiz_Project_Leiva/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NO SEAS SAPO

# %%
import os
os.environ['KAGGLE_USERNAME'] = "xxxxxx"
os.environ['KAGGLE_KEY'] = "xxxxxx"

# !kaggle datasets download -d DATASET_LINK

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-711af4a5-31e9-4875-b2ac-0bffdbfc6bac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-711af4a5-31e9-4875-b2ac-0bffdbfc6bac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.makedirs("/root/.kaggle", exist_ok=True)
# !mv kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows
# Out:
# Dataset URL: https://www.kaggle.com/datasets/harshitshankhdhar/imdb-dataset-of-top-1000-movies-and-tv-shows
# License(s): CC0-1.0
# ...
#   0% 0.00/175k [00:00<?, ?B/s]
# 100% 175k/175k [00:00<00:00, 379MB/s]

# %%
# !unzip *.zip
# Out:
# Archive:  imdb-dataset-of-top-1000-movies-and-tv-shows.zip
#   inflating: imdb_top_1000.csv

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'imdb-dataset-of-top-1000-movies-and-tv-shows.zip',
#  'imdb_top_1000.csv',
#  'sample_data']

# %%
import pandas as pd

df = pd.read_csv("imdb_top_1000.csv")
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
transactions = df[['Star1','Star2','Star3','Star4']].values.tolist()

# %%
# !pip install mlxtend

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

frequent = apriori(df_encoded, min_support=0.01, use_colnames=True)
frequent.sort_values("support", ascending=False).head()
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
#    support          itemsets
# 7    0.017  (Robert De Niro)
# 8    0.014       (Tom Hanks)
# 0    0.013       (Al Pacino)
# 1    0.012       (Brad Pitt)
# 3    0.012  (Clint Eastwood)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...
